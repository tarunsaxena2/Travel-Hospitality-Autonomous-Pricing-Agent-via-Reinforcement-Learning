# %% [markdown]
# # Week 1 — MDP & Environment Design

# %% [markdown]
# ## 1. Problem Statement

# %% [markdown]
# ## 2. State Space

# %% [markdown]
# ## 3. Action Space

# %% [markdown]
# ## 4. Reward Function

# %% [markdown]
# ## 5. Transition Dynamics
