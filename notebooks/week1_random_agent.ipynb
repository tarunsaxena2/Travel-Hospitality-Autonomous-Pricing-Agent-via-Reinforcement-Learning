# %% [markdown]
# # Week 1 — Random Agent Baseline

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ## 2. Random Agent Definition

# %% [markdown]
# ## 3. Test Run

# %% [markdown]
# ## 4. Notes on Gymnasium API
